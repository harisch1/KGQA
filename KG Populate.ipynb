# %%
# !pip install py2neo
# !pip install wikipedia
# !pip install spacy
# !pip install pandas
# !pip install numpy
# !pip install tqdm
# !pip install jupyterlab
# !pip install neo4j
# !pip install pywikibot
# !pip install sklearn
# Out:
# Requirement already satisfied: py2neo in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (2021.2.3)
# Requirement already satisfied: urllib3 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (1.26.9)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: six>=1.15.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: certifi in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (2021.10.8)
# Requirement already satisfied: monotonic in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (1.6)
# Requirement already satisfied: packaging in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from py2neo) (21.3)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from py2neo) (2.11.2)
# Requirement already satisfied: pytz in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from interchange~=2021.0.4->py2neo) (2022.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from packaging->py2neo) (3.0.7)
# Requirement already satisfied: wikipedia in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from wikipedia) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from wikipedia) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->wikipedia) (2.3.1)
# Requirement already satisfied: spacy in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (3.2.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.22.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (8.0.15)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: jinja2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (3.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.7.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: click<8.1.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (8.0.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.9.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (4.63.1)
# Requirement already satisfied: setuptools in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (58.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.27.1)
# Requirement already satisfied: colorama in c:\users\haris\appdata\roaming\python\python39\site-packages (from click<8.1.0->spacy) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->spacy) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: pandas in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\haris\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (1.22.3)
# Requirement already satisfied: tqdm in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (4.63.1)
# Requirement already satisfied: colorama in c:\users\haris\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: jupyterlab in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (3.3.2)
# Requirement already satisfied: packaging in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab) (21.3)
# Requirement already satisfied: jupyterlab-server~=2.10 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab) (2.12.0)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab) (0.3.7)
# Requirement already satisfied: ipython in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyterlab) (8.2.0)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab) (1.16.0)
# Requirement already satisfied: jinja2>=2.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab) (3.1.1)
# Requirement already satisfied: jupyter-core in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyterlab) (4.9.2)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyterlab) (6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-server~=1.4->jupyterlab) (22.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (21.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (3.5.0)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-server~=1.4->jupyterlab) (5.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-server~=1.4->jupyterlab) (7.2.0)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (6.4.5)
# Requirement already satisfied: websocket-client in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (1.3.2)
# Requirement already satisfied: pywinpty in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (2.0.5)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (5.2.0)
# Requirement already satisfied: prometheus-client in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (0.13.3)
# Requirement already satisfied: Send2Trash in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab) (1.8.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-core->jupyterlab) (303)
# Requirement already satisfied: json5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.4.0)
# Requirement already satisfied: requests in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.27.1)
# Requirement already satisfied: babel in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.9.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (0.4)
# Requirement already satisfied: notebook<7 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbclassic~=0.2->jupyterlab) (6.4.10)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbclassic~=0.2->jupyterlab) (0.1.0)
# Requirement already satisfied: backcall in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: decorator in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: colorama in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab) (58.1.0)
# Requirement already satisfied: matplotlib-inline in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipython->jupyterlab) (3.0.28)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from packaging->jupyterlab) (3.0.7)
# Requirement already satisfied: idna>=2.8 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from anyio>=3.1.0->jupyter-server~=1.4->jupyterlab) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from anyio>=3.1.0->jupyter-server~=1.4->jupyterlab) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.4->jupyterlab) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.4->jupyterlab) (1.5.4)
# Requirement already satisfied: defusedxml in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.8.4)
# Requirement already satisfied: testpath in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (4.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.5.13)
# Requirement already satisfied: bleach in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.1.2)
# Requirement already satisfied: ipython-genutils in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab) (0.2.0)
# Requirement already satisfied: ipykernel in c:\users\haris\appdata\roaming\python\python39\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab) (6.10.0)
# Requirement already satisfied: wcwidth in c:\users\haris\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from babel->jupyterlab-server~=2.10->jupyterlab) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (1.26.9)
# Requirement already satisfied: pure-eval in c:\users\haris\appdata\roaming\python\python39\site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\haris\appdata\roaming\python\python39\site-packages (from stack-data->ipython->jupyterlab) (2.0.5)
# Requirement already satisfied: executing in c:\users\haris\appdata\roaming\python\python39\site-packages (from stack-data->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\haris\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->jupyter-server~=1.4->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab) (0.5.1)
# Requirement already satisfied: psutil in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab) (5.9.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab) (1.6.0)
# Requirement already satisfied: pycparser in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab) (2.21)
# Requirement already satisfied: neo4j in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (4.4.2)
# Requirement already satisfied: pytz in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from neo4j) (2022.1)
# Requirement already satisfied: pywikibot in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (7.1.0)
# Requirement already satisfied: requests>=2.20.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pywikibot) (2.27.1)
# Requirement already satisfied: setuptools>=38.5.2 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from pywikibot) (58.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.20.1->pywikibot) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.20.1->pywikibot) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.20.1->pywikibot) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.20.1->pywikibot) (2.0.12)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 11.8 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
#      ---------------------------------------- 36.9/36.9 MB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.6 in c:\users\haris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->sklearn) (1.22.3)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      -------------------------------------- 307.0/307.0 KB 4.8 MB/s eta 0:00:00
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 scipy-1.8.0 sklearn-0.0 threadpoolctl-3.1.0

# %%
# !python -m spacy download en_core_web_lg

# %%
import json
import re
import urllib
from pprint import pprint
import time
from tqdm import tqdm

from py2neo import Node, Graph, Relationship, NodeMatcher
from py2neo.bulk import merge_nodes

import numpy as np
import pandas as pd
import wikipedia
from sklearn.metrics.pairwise import cosine_similarity

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.matcher import Matcher
from spacy.tokens import Doc, Span, Token

print(spacy.__version__)
# Out:
# 3.2.4

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
VERBS = ['ROOT', 'advcl']
OBJECTS = ["dobj", "dative", "attr", "oprd", 'pobj']
ENTITY_LABELS = ['PERSON', 'NORP', 'GPE', 'ORG', 'FAC', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART']

api_key = open('.api_key').read()

non_nc = spacy.load('en_core_web_md')

nlp = spacy.load('en_core_web_md')
nlp.add_pipe('merge_noun_chunks')

print(non_nc.pipe_names)
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'merge_noun_chunks']

# %%
def remove_special_characters(text):
    
    regex = re.compile(r'[\n\r\t]')
    clean_text = regex.sub(" ", text)
    
    return clean_text


def remove_stop_words_and_punct(text, print_text=False):
    
    result_ls = []
    rsw_doc = non_nc(text)
    
    for token in rsw_doc:
        if print_text:
            print(token, token.is_stop)
            print('--------------')
        if not token.is_stop and not token.is_punct:
            result_ls.append(str(token))
    
    result_str = ' '.join(result_ls)

    return result_str


def create_svo_lists(doc, print_lists):
    
    subject_ls = []
    verb_ls = []
    object_ls = []

    for token in doc:
        if token.dep_ in SUBJECTS:
            subject_ls.append((token.lower_, token.idx))
        elif token.dep_ in VERBS:
            verb_ls.append((token.lemma_, token.idx))
        elif token.dep_ in OBJECTS:
            object_ls.append((token.lower_, token.idx))

    if print_lists:
        print('SUBJECTS: ', subject_ls)
        print('VERBS: ', verb_ls)
        print('OBJECTS: ', object_ls)
    
    return subject_ls, verb_ls, object_ls


def remove_duplicates(tup, tup_posn):
    
    check_val = set()
    result = []
    
    for i in tup:
        if i[tup_posn] not in check_val:
            result.append(i)
            check_val.add(i[tup_posn])
            
    return result


def remove_dates(tup_ls):
    
    clean_tup_ls = []
    for entry in tup_ls:
        if not entry[2].isdigit():
            clean_tup_ls.append(entry)
    return clean_tup_ls


def create_svo_triples(text, print_lists=False):
    
    clean_text = remove_special_characters(text)
    doc = nlp(clean_text)
    subject_ls, verb_ls, object_ls = create_svo_lists(doc, print_lists=print_lists)
    
    graph_tup_ls = []
    dedup_tup_ls = []
    clean_tup_ls = []
    
    for subj in subject_ls: 
        for obj in object_ls:
            
            dist_ls = []
            
            for v in verb_ls:
                
                # Assemble a list of distances between each object and each verb
                dist_ls.append(abs(obj[1] - v[1]))
                
            # Get the index of the verb with the smallest distance to the object 
            # and return that verb
            index_min = min(range(len(dist_ls)), key=dist_ls.__getitem__)
            
            # Remve stop words from subjects and object.  Note that we do this a bit
            # later down in the process to allow for proper sentence recognition.

            no_sw_subj = remove_stop_words_and_punct(subj[0])
            no_sw_obj = remove_stop_words_and_punct(obj[0])
            
            # Add entries to the graph iff neither subject nor object is blank
            if no_sw_subj and no_sw_obj:
                tup = (no_sw_subj, verb_ls[index_min][0], no_sw_obj)
                graph_tup_ls.append(tup)
        
        #clean_tup_ls = remove_dates(graph_tup_ls)
    
    dedup_tup_ls = remove_duplicates(graph_tup_ls, 2)
    clean_tup_ls = remove_dates(dedup_tup_ls)
    
    return clean_tup_ls

# %%
def get_obj_properties(tup_ls):
    
    init_obj_tup_ls = []
    
    for tup in tup_ls:

        try:
            text, node_label_ls, url = query_google(tup[2], api_key, limit=1)
            new_tup = (tup[0], tup[1], tup[2], text[0], node_label_ls[0], url[0])
        except:
            new_tup = (tup[0], tup[1], tup[2], [], [], [])
        
        init_obj_tup_ls.append(new_tup)
        
    return init_obj_tup_ls


def add_layer(tup_ls):

    svo_tup_ls = []
    
    for tup in tup_ls:
        
        if tup[3]:
            svo_tup = create_svo_triples(tup[3])
            svo_tup_ls.extend(svo_tup)
        else:
            continue
    
    return get_obj_properties(svo_tup_ls)
        

def subj_equals_obj(tup_ls):
    
    new_tup_ls = []
    
    for tup in tup_ls:
        if tup[0] != tup[2]:
            new_tup_ls.append((tup[0], tup[1], tup[2], tup[3], tup[4], tup[5]))
            
    return new_tup_ls


def check_for_string_labels(tup_ls):
    # This is for an edge case where the object does not get fully populated
    # resulting in the node labels being assigned to string instead of list.
    # This may not be strictly necessary and the lines using it are commnted out
    # below.  Run this function if you come across this case.
    
    clean_tup_ls = []
    
    for el in tup_ls:
        if isinstance(el[2], list):
            clean_tup_ls.append(el)
            
    return clean_tup_ls


def create_word_vectors(tup_ls):

    new_tup_ls = []
    
    for tup in tup_ls:
        if tup[3]:
            doc = nlp(tup[3])
            new_tup = (tup[0], tup[1], tup[2], tup[3], tup[4], tup[5], doc.vector)
        else:
            new_tup = (tup[0], tup[1], tup[2], tup[3], tup[4], tup[5], np.random.uniform(low=-1.0, high=1.0, size=(300,)))
        new_tup_ls.append(new_tup)
        
    return new_tup_ls

# %%
text= wikipedia.page('the starry night').content
text

# %%
# %%time
initial_tup_ls = create_svo_triples(text, print_lists=False)

# %%
initial_tup_ls
# Out:
# [('starry night', 'be', 'canvas'),
#  ('starry night', 'be', 'painting'),
#  ('starry night', 'be', 'dutch post impressionist painter'),
#  ('starry night', 'paint', 'june'),
#  ('starry night', 'depict', 'view'),
#  ('starry night', 'depict', 'east facing window'),
#  ('starry night', 'depict', 'asylum room'),
#  ('starry night', 'depict', 'provence'),
#  ('starry night', 'be', 'sunrise'),
#  ('starry night', 'be', 'addition'),
#  ('starry night', 'be', 'imaginary village'),
#  ('starry night', 'be', 'permanent collection'),
#  ('starry night', 'be', 'museum'),
#  ('starry night', 'be', 'modern art'),
#  ('starry night', 'be', 'new york city'),
#  ('starry night', 'regard', 'lillie p. bliss bequest'),
#  ('starry night', 'regard', 'van gogh magnum opus'),
#  ('starry night', 'be', 'recognized paintings'),
#  ('starry night', 'be', 'western art'),
#  ('starry night', 'be', 'aftermath'),
#  ('starry night', 'be', '23 december 1888 breakdown'),
#  ('starry night', 'admit', 'self mutilation'),
#  ('starry night', 'admit', 'left ear'),
#  ('starry night', 'admit', 'saint paul de mausole lunatic asylum'),
#  ('starry night', 'house', 'monastery'),
#  ('starry night', 'cater', 'wealthy'),
#  ('starry night', 'allow', 'second story bedroom'),
#  ('starry night', 'allow', 'use'),
#  ('starry night', 'allow', 'painting studio'),
#  ('starry night', 'allow', 'year'),
#  ('starry night', 'continue', 'asylum'),
#  ('starry night', 'continue', 'paintings'),
#  ('starry night', 'continue', 'arles'),
#  ('starry night', 'produce', 'period'),
#  ('starry night', 'produce', 'best known works'),
#  ('starry night', 'produce', 'career'),
#  ('starry night', 'produce', 'irises'),
#  ('starry night', 'produce', 'j. paul getty museum'),
#  ('starry night', 'paint', 'september'),
#  ('starry night', 'paint', 'musée'),
#  ('starry night', 'paint', '18 june'),
#  ('starry night', 'say', 'brother'),
#  ('starry night', 'say', 'new study'),
#  ('starry night', 'say', 'starry sky'),
#  ('starry night', 'paint', 'day'),
#  ('starry night', 'paint', 'van gogh ground floor studio'),
#  ('starry night', 'identify', 'memory'),
#  ('starry night', 'face', 'bedroom window'),
#  ('starry night', 'face', 'east'),
#  ('starry night', 'face', 'variations'),
#  ('starry night', 'face', 'fewer times'),
#  ('starry night', 'write', 'starry night'),
#  ('starry night', 'write', 'iron barred window'),
#  ('starry night', 'write', 'enclosed square'),
#  ('starry night', 'write', 'wheat'),
#  ('starry night', 'depict', 'morning'),
#  ('starry night', 'depict', 'glory'),
#  ('starry night', 'depict', 'different times'),
#  ('starry night', 'depict', 'weather conditions'),
#  ('starry night', 'depict', 'sunrise moonrise sunshine filled days'),
#  ('starry night', 'allow', 'rain'),
#  ('starry night', 'allow', 'bedroom'),
#  ('starry night', 'base', 'sketches'),
#  ('starry night', 'base', 'ink'),
#  ('starry night', 'base', 'paper'),
#  ('starry night', 'base', 'newer variations'),
#  ('starry night', 'base', 'previous versions'),
#  ('starry night', 'be', 'diagonal line'),
#  ('starry night', 'be', 'right'),
#  ('starry night', 'be', 'low rolling hills'),
#  ('starry night', 'be', 'alpilles mountains'),
#  ('starry night', 'be', 'versions'),
#  ('starry night', 'be', 'far wall'),
#  ('starry night', 'telescope', 'wheat field'),
#  ('starry night', 'bring', 'f717 wheat field'),
#  ('starry night', 'bring', 'cypresses'),
#  ('starry night', 'bring', 'trees'),
#  ('starry night', 'bring', 'picture plane'),
#  ('starry night', 'be', 'f611 mountainous landscape'),
#  ('starry night', 'be', 'saint rémy'),
#  ('starry night', 'make', 'copenhagen'),
#  ('starry night', 'make', 'number'),
#  ('starry night', 'be', 'enclosed wheatfield'),
#  ('starry night', 'be', 'storm'),
#  ('starry night', 'be', 'studio'),
#  ('starry night', 'mention', '9 june letter'),
#  ('starry night', 'describe', 'days'),
#  ('starry night', 'describe', 'second'),
#  ('starry night', 'describe', 'landscapes'),
#  ('starry night', 'be', 'letter'),
#  ('starry night', 'be', 'sister'),
#  ('starry night', 'be', '16 june'),
#  ('starry night', 'be', 'f719 green wheat field'),
#  ('starry night', 'be', 'cypress'),
#  ('starry night', 'be', 'prague'),
#  ('starry night', 'F1548', 'plein air'),
#  ('starry night', 'be', 'new york'),
#  ('starry night', 'be', 'study'),
#  ('starry night', 'state', 'theo'),
#  ('starry night', 'be', 'nocturne'),
#  ('starry night', 'be', 'series'),
#  ('starry night', 'be', 'views'),
#  ('starry night', 'write', 'early june'),
#  ('starry night', 'write', 'countryside'),
#  ('starry night', 'write', 'window'),
#  ('starry night', 'determine', 'morning star'),
#  ('starry night', 'determine', 'dawn'),
#  ('starry night', 'determine', 'spring'),
#  ('starry night', 'be', 'time'),
#  ('starry night', 'be', 'viewer right'),
#  ('starry night', 'be', 'cypress tree'),
#  ('starry night', 'be', 'venus'),
#  ('starry night', 'be', 'picture'),
#  ('starry night', 'be', 'moon'),
#  ('starry night', 'be', 'waning crescent'),
#  ('starry night', 'see', 'interpretations'),
#  ('starry night', 'be', 'van gogh cell'),
#  ('starry night', 'be', 'village'),
#  ('starry night', 'be', 'sketch f1541v'),
#  ('starry night', 'think', 'hillside'),
#  ('starry night', 'think', 'provençal'),
#  ('starry night', 'think', 'van gogh'),
#  ('starry night', 'think', 'nuenen period'),
#  ('starry night', 'think', 'reminisces'),
#  ('starry night', 'think', 'north'),
#  ('starry night', 'think', 'landscape'),
#  ('starry night', 'think', 'reverse f1541r'),
#  ('starry night', 'say', 'large number'),
#  ('starry night', 'say', 'letters'),
#  ('starry night', 'include', 'list'),
#  ('starry night', 'refer', 'paris'),
#  ('starry night', 'refer', 'night study'),
#  ('starry night', 'refer', 'things'),
#  ('starry night', 'refer', 'little good'),
#  ('starry night', 'include', 'blue hills'),
#  ('starry night', 'include', 'quarry'),
#  ('starry night', 'decide', 'batch'),
#  ('starry night', 'be', 'order'),
#  ('starry night', 'be', 'money'),
#  ('starry night', 'be', 'postage'),
#  ('starry night', 'refer', 'émile bernard'),
#  ('starry night', 'refer', 'late november'),
#  ('starry night', 'argue', 'failure'),
#  ('starry night', 'argue', 'bernard'),
#  ('starry night', 'prefer', 'nature'),
#  ('starry night', 'prefer', 'abstractions'),
#  ('starry night', 'recount', 'imagination'),
#  ('starry night', 'recount', 'experiences'),
#  ('starry night', 'live', 'weeks'),
#  ('starry night', 'live', 'autumn'),
#  ('starry night', 'know', 'abstraction'),
#  ('starry night', 'be', 'delusion'),
#  ('starry night', 'allow', 'brick wall'),
#  ('starry night', 'allow', 'stars'),
#  ('starry night', 'refer', 'fill'),
#  ('starry night', 'refer', 'expressionistic swirls'),
#  ('starry night', 'refer', 'upper center portion'),
#  ('starry night', 'refer', 'pictorial elements'),
#  ('starry night', 'refer', 'vincent'),
#  ('starry night', 'feel', 'new canvases'),
#  ('starry night', 'feel', 'moonlight'),
#  ('starry night', 'feel', 'style'),
#  ('starry night', 'feel', 'real sentiment'),
#  ('starry night', 'feel', 'early november'),
#  ('starry night', 'be', 'previous letter'),
#  ('starry night', 'be', 'qualities'),
#  ('starry night', 'be', 'long run'),
#  ('starry night', 'urge', 'long sinuous lines'),
#  ('starry night', 'urge', 'consignment'),
#  ('starry night', 'urge', 'means'),
#  ('starry night', '"But', 'drawing style'),
#  ('starry night', '"But', 'entanglement'),
#  ('starry night', '"But', 'masses'),
#  ('starry night', 'defend', 'practices'),
#  ('starry night', 'defend', 'gauguin'),
#  ('starry night', 'defend', 'preferred method'),
#  ('starry night', 'favor', 'impressionists'),
#  ('starry night', 'paint', 'sunflowers'),
#  ('starry night', 'belong', 'small series'),
#  ('starry night', 'limit', 'nocturnes'),
#  ('starry night', 'limit', 'difficulties'),
#  ('starry night', 'limit', 'scenes'),
#  ('starry night', 'be', 'night'),
#  ('starry night', 'be', 'café terrace'),
#  ('starry night', 'paint', 'early september'),
#  ('starry night', 'follow', 'rhône'),
#  ('starry night', 'provide', 'insight'),
#  ('starry night', 'provide', 'intentions'),
#  ('starry night', 'provide', 'night studies'),
#  ('starry night', 'write', 'arrival'),
#  ('starry night', 'write', 'february'),
#  ('starry night', 'write', 'field'),
#  ('starry night', 'write', 'ripe wheat'),
#  ('starry night', 'write', 'beautiful nights'),
#  ('starry night', 'go', 'daytime'),
#  ('starry night', 'go', 'green meadow'),
#  ('starry night', 'compare', 'dandelions'),
#  ('starry night', 'compare', 'dots'),
#  ('starry night', 'take', 'map'),
#  ('starry night', 'take', 'train'),
#  ('starry night', 'reach', 'earth'),
#  ('starry night', 'reach', 'death'),
#  ('starry night', 'reach', 'star'),
#  ('starry night', 'reach', 'point'),
#  ('starry night', 'disillusion', 'life'),
#  ('starry night', 'appear', 'religion'),
#  ('starry night', 'appear', 'belief'),
#  ('starry night', 'appear', 'afterlife'),
#  ('starry night', 'appear', 'ambivalence'),
#  ('starry night', 'confess', 'tremendous need'),
#  ('starry night', 'go', 'word'),
#  ('starry night', 'write', 'dimension'),
#  ('starry night', 'be', 'night sky'),
#  ('starry night', 'be', 'terrible things'),
#  ('starry night', 'have', 'hemisphere'),
#  ('starry night', 'write', 'planet'),
#  ('starry night', 'state', 'return'),
#  ('starry night', 'state', 'romantic'),
#  ('starry night', 'highlight', 'religious ideas'),
#  ('starry night', 'highlight', 'expressionistic aspects'),
#  ('starry night', 'say', 'pressure'),
#  ('starry night', 'say', 'feeling'),
#  ('starry night', 'theorize', 'visionary'),
#  ('starry night', 'theorize', 'religious mood'),
#  ('starry night', 'theorize', 'work'),
#  ('starry night', 'reveal', 'reference'),
#  ('starry night', 'reveal', 'new testament book'),
#  ('starry night', 'reveal', 'revelation'),
#  ('starry night', 'reveal', 'apocalyptic theme'),
#  ('starry night', 'reveal', 'woman'),
#  ('starry night', 'reveal', 'pain'),
#  ('starry night', 'reveal', 'birth'),
#  ('starry night', 'reveal', 'sun'),
#  ('starry night', 'profess', 'dragon'),
#  ('starry night', 'profess', 'volume'),
#  ('starry night', 'profess', 'image'),
#  ('starry night', 'profess', 'mother'),
#  ('starry night', 'profess', 'clouds'),
#  ('starry night', 'profess', 'olive trees'),
#  ('starry night', 'call', 'pendant'),
#  ('starry night', 'call', 'schapiro approach'),
#  ('starry night', 'call', 'visionary painting'),
#  ('starry night', 'write', 'state'),
#  ('starry night', 'write', 'great agitation'),
#  ('starry night', 'write', 'hallucinatory character'),
#  ('starry night', 'take', 'pains'),
#  ('starry night', 'compare', 'van gogh incapacitating breakdowns'),
#  ('starry night', 'compare', 'van gogh religiously inclined longing'),
#  ('starry night', 'call', 'poetry'),
#  ('starry night', 'call', 'walt whitman'),
#  ('starry night', 'call', 'final absorption'),
#  ('starry night', 'call', 'artist'),
#  ('starry night', 'call', 'cosmos'),
#  ('starry night', 'praise', 'forgotten sensation'),
#  ('starry night', 'praise', 'threshold'),
#  ('starry night', 'praise', 'eternity'),
#  ('starry night', 'praise', 'schapiro eloquent interpretation'),
#  ('starry night', 'praise', 'apocalyptic vision'),
#  ('starry night', 'praise', 'symbolist theory'),
#  ('starry night', 'assert', 'joseph dreams'),
#  ('starry night', 'assert', 'old testament book'),
#  ('starry night', 'assert', 'genesis'),
#  ('starry night', 'assert', 'purely symbolic terms'),
#  ('starry night', 'find', 'tree'),
#  ('starry night', 'find', 'mediterranean countries'),
#  ('starry night', 'find', 'symbolist subtext'),
#  ('starry night', 'say', 'traditional religious subject'),
#  ('starry night', 'say', 'disguise'),
#  ('starry night', 'cite', 'sublimated image'),
#  ('starry night', 'cite', 'deepest religious feelings'),
#  ('starry night', 'cite', 'van gogh avowed admiration'),
#  ('starry night', 'cite', 'eugène delacroix'),
#  ('starry night', 'theorize', 'yellow'),
#  ('starry night', 'theorize', 'christ'),
#  ('starry night', 'theorize', 'colors'),
#  ('starry night', 'criticize', 'schapiro loevgren biblical interpretations'),
#  ('starry night', 'be', 'reading'),
#  ('starry night', 'be', 'crescent moon'),
#  ('starry night', 'say', 'elements'),
#  ('starry night', 'be', 'symbolic meaning'),
#  ('starry night', 'be', 'consolation'),
#  ('starry night', 'be', 'light'),
#  ('starry night', 'be', 'symbolist interpretations'),
#  ('starry night', 'prove', 'topographical elements'),
#  ('starry night', 'prove', 'van gogh view'),
#  ('starry night', 'identify', 'asylum window'),
#  ('starry night', 'suggest', 'gibbous moon'),
#  ('starry night', 'suggest', 'traditional image'),
#  ('starry night', 'recount', 'resulting crescent'),
#  ('starry night', 'recount', 'remnant'),
#  ('starry night', 'recount', 'original gibbous version'),
#  ('starry night', 'recount', 'van gogh interest'),
#  ('starry night', 'recount', 'writings'),
#  ('starry night', 'recount', 'victor hugo'),
#  ('starry night', 'recount', 'possible inspiration'),
#  ('starry night', 'provide', 'detailed discussion'),
#  ('starry night', 'provide', 'publicized advances'),
#  ('starry night', 'assert', 'astronomy'),
#  ('starry night', 'assert', 'place'),
#  ('starry night', 'assert', 'van gogh lifetime'),
#  ('starry night', 'mention', 'astronomer camille flammarion'),
#  ('starry night', 'mention', 'flammarion popular illustrated publications'),
#  ('starry night', 'see', 'drawings'),
#  ('starry night', 'see', 'spiral nebulae'),
#  ('starry night', 'interpret', 'telescopes'),
#  ('starry night', 'interpret', 'swirling figure'),
#  ('starry night', 'interpret', 'central portion'),
#  ('starry night', 'interpret', 'sky'),
#  ('starry night', 'interpret', 'spiral galaxy'),
#  ('starry night', 'assert', 'popular media'),
#  ('starry night', 'represent', 'van gogh understanding'),
#  ('starry night', 'represent', 'living dynamic place'),
#  ('starry night', 'conduct', 'astronomical study'),
#  ('starry night', 'share', 'boime'),
#  ('starry night', 'share', 'entire career'),
#  ('starry night', 'share', 'u.c.l.a'),
#  ('starry night', 'share', 'boime certainty'),
#  ('starry night', 'share', 'regard'),
#  ('starry night', 'concur', 'constellation aries'),
#  ('starry night', 'concur', 'visibility'),
#  ('starry night', 'see', 'depiction'),
#  ('starry night', 'give', 'credit'),
#  ('starry night', 'give', 'original'),
#  ('starry night', 'give', 'anglo irish astronomer william parsons'),
#  ('starry night', 'evoke', 'wind'),
#  ('starry night', 'evoke', 'mistral'),
#  ('starry night', 'evoke', 'profound effect'),
#  ('starry night', 'be', 'seven months'),
#  ('starry night', 'be', 'breakdown'),
#  ('starry night', 'theorize', 'july'),
#  ('starry night', 'theorize', 'blue'),
#  ('starry night', 'theorize', 'horizon'),
#  ('starry night', 'identify', 'recollection'),
#  ('starry night', 'identify', 'van gogh dutch homeland'),
#  ('starry night', 'be', 'sketch'),
#  ('starry night', 'be', 'town'),
#  ('starry night', 'be', 'case'),
#  ('starry night', 'be', 'imaginary component'),
#  ('starry night', 'associate', 'asylum bedroom'),
#  ('starry night', 'associate', 'european culture'),
#  ('starry night', 'be', 'subject'),
#  ('starry night', 'be', 'open debate'),
#  ('starry night', 'be', 'april 1888 letter'),
#  ('starry night', 'refer', 'funereal cypresses'),
#  ('starry night', 'be', 'stately oaks'),
#  ('starry night', 'like', 'thoughts'),
#  ('starry night', 'like', 'canvases'),
#  ('starry night', 'mention', 'studies'),
#  ('starry night', 'mention', 'difficult shade'),
#  ('starry night', 'suggest', 'green'),
#  ('starry night', 'suggest', 'formal qualities'),
#  ('starry night', 'refer', 'symbolic connotation'),
#  ('starry night', 'refer', 'vague symbol'),
#  ('starry night', 'call', 'human striving'),
#  ('starry night', 'call', 'symbolic counterpart'),
#  ('starry night', 'call', 'striving'),
#  ('starry night', 'call', 'infinite'),
#  ('starry night', 'say', 'non orthodox channels'),
#  ('starry night', 'provide', 'rustic natural obelisks'),
#  ('starry night', 'provide', 'link'),
#  ('starry night', 'provide', 'heavens'),
#  ('starry night', 'remind', 'reader'),
#  ('starry night', 'say', 'arbitrary collage'),
#  ('starry night', 'say', 'separate motifs'),
#  ('starry night', 'claim', 'van gogh room'),
#  ('starry night', 'assert', 'products'),
#  ('starry night', 'assert', 'van gogh imagination'),
#  ('starry night', 'say', 'certain'),
#  ('starry night', 'say', 'pictures'),
#  ('starry night', 'serve', 'reason'),
#  ('starry night', 'serve', 'depth'),
#  ('starry night', 'serve', 'brightness'),
#  ('starry night', 'use', 'van gogh statement'),
#  ('starry night', 'use', 'exaggeration'),
#  ('starry night', 'be', 'arrangement'),
#  ('starry night', 'be', 'argument'),
#  ('starry night', 'be', 'amalgam'),
#  ('starry night', 'be', 'images'),
#  ('starry night', 'speak', 'synonym'),
#  ('starry night', 'speak', 'composition'),
#  ('starry night', 'speak', 'fact'),
#  ('starry night', 'speak', 'comment'),
#  ('starry night', 'call', 'white cloud'),
#  ('starry night', 'call', 'mountains'),
#  ('starry night', 'call', 'exaggerations'),
#  ('starry night', 'contort', 'ancient woodcuts'),
#  ('starry night', 'acknowledge', 'realistic non composite views'),
#  ('starry night', 'acknowledge', 'subjects'),
#  ('starry night', 'be', 'exaggerated color'),
#  ('starry night', 'be', 'type'),
#  ('starry night', 'criticize', 'search'),
#  ('starry night', 'use', 'occasions'),
#  ('starry night', 'use', 'word arrangement'),
#  ('starry night', 'use', 'color'),
#  ('starry night', 'use', 'way'),
#  ('starry night', 'write', 'term'),
#  ('starry night', 'write', 'january'),
#  ('starry night', 'move', 'colours'),
#  ('starry night', 'intensify', 'pure oranges'),
#  ('starry night', 'intensify', 'flesh'),
#  ('starry night', 'intensify', 'tones'),
#  ('starry night', 'intensify', 'chromes'),
#  ('starry night', 'intensify', 'pinks'),
#  ('starry night', 'devise', 'olive veronese greens'),
#  ('starry night', 'devise', 'impressionist arrangement'),
#  ('starry night', 'be', 'la berceuse'),
#  ('starry night', 'be', 'realistic portrait'),
#  ('starry night', 'be', 'augustine roulin'),
#  ('starry night', 'be', 'imaginative floral background'),
#  ('starry night', 'be', 'meadow'),
#  ('starry night', 'discuss', 'hallucinatory vision'),
#  ('starry night', 'discuss', 'context'),
#  ('starry night', 'discuss', 'van gogh mental illness'),
#  ('starry night', 'know', 'temporal lobe epilepsy'),
#  ('starry night', 'know', 'antiquity'),
#  ('starry night', 'cause', 'limbs'),
#  ('starry night', 'cause', 'jerk'),
#  ('starry night', 'call', 'falling sickness'),
#  ('starry night', 'call', 'mind'),
#  ('starry night', 'call', 'thought'),
#  ('starry night', 'symptom', 'brain'),
#  ('starry night', 'symptom', 'bizarre dramatic behavior'),
#  ('starry night', 'symptom', 'seizures'),
#  ('starry night', 'experience', 'electrical impulses'),
#  ('starry night', 'experience', 'second breakdown'),
#  ('starry night', 'throw', 'mid'),
#  ('starry night', 'throw', 'heightened reality'),
#  ('starry night', 'send', 'ordinary eyes'),
#  ('starry night', 'send', '28 september'),
#  ('starry night', 'become', 'caretaker'),
#  ('starry night', 'become', 'van gogh legacy'),
#  ('starry night', 'poet', 'julien leclercq'),
#  ('starry night', 'sell', 'gauguin old friend'),
#  ('starry night', 'buy', 'schuffenecker'),
#  ('starry night', 'own', 'oldenzeel gallery'),
#  ('starry night', 'own', 'rotterdam'),
#  ('starry night', 'own', 'georgette p. van stolk'),
#  ('starry night', 'be', 'paul rosenberg'),
#  ('starry night', 'be', 'rosenberg'),
#  ('starry night', 'investigate', 'scientists'),
#  ('starry night', 'investigate', 'rochester institute'),
#  ('starry night', 'investigate', 'technology'),
#  ('starry night', 'exhibit', 'rare pigment indian yellow'),
#  ('starry night', 'exhibit', 'van gogh starry night'),
#  ('starry night', 'see', 'baldin collection vincent'),
#  ('starry night', 'see', 'don mclean'),
#  ('starry night', 'see', 'tribute'),
#  ('starry night', 'see', 'vincent van gogh timbres'),
#  ('starry night', 'Citations Letters Sources', 'henri dutilleux'),
#  ('starry night', 'the Starry Night', 'metropolitan museum'),
#  ('starry night', 'the Starry Night', 'art libraries'),
#  ('starry night', 'the Starry Night', 'material'),
#  ('starry night', 'the Starry Night', 'aerial photo'),
#  ('starry night', 'the Starry Night', 'vincent bedroom archived'),
#  ('starry night', 'the Starry Night', 'wayback machine vincent van gogh'),
#  ('starry night', 'the Starry Night', 'history')]

# %%
# %%time
init_obj_tup_ls = get_obj_properties(initial_tup_ls)
new_layer_ls = add_layer(init_obj_tup_ls)
starter_edge_ls = init_obj_tup_ls + new_layer_ls
edge_ls = subj_equals_obj(starter_edge_ls)
# clean_edge_ls = check_for_string_labels(edge_ls)
# clean_edge_ls[0:3]
clean_edge_ls = edge_ls

# %%
edges_word_vec_ls = create_word_vectors(edge_ls)

# %%
edge_ls
# Out:
# [('starry night', 'be', 'canvas', [], [], []),
#  ('starry night', 'be', 'painting', [], [], []),
#  ('starry night', 'be', 'dutch post impressionist painter', [], [], []),
#  ('starry night', 'paint', 'june', [], [], []),
#  ('starry night', 'depict', 'view', [], [], []),
#  ('starry night', 'depict', 'east facing window', [], [], []),
#  ('starry night', 'depict', 'asylum room', [], [], []),
#  ('starry night', 'depict', 'provence', [], [], []),
#  ('starry night', 'be', 'sunrise', [], [], []),
#  ('starry night', 'be', 'addition', [], [], []),
#  ('starry night', 'be', 'imaginary village', [], [], []),
#  ('starry night', 'be', 'permanent collection', [], [], []),
#  ('starry night', 'be', 'museum', [], [], []),
#  ('starry night', 'be', 'modern art', [], [], []),
#  ('starry night', 'be', 'new york city', [], [], []),
#  ('starry night', 'regard', 'lillie p. bliss bequest', [], [], []),
#  ('starry night', 'regard', 'van gogh magnum opus', [], [], []),
#  ('starry night', 'be', 'recognized paintings', [], [], []),
#  ('starry night', 'be', 'western art', [], [], []),
#  ('starry night', 'be', 'aftermath', [], [], []),
#  ('starry night', 'be', '23 december 1888 breakdown', [], [], []),
#  ('starry night', 'admit', 'self mutilation', [], [], []),
#  ('starry night', 'admit', 'left ear', [], [], []),
#  ('starry night', 'admit', 'saint paul de mausole lunatic asylum', [], [], []),
#  ('starry night', 'house', 'monastery', [], [], []),
#  ('starry night', 'cater', 'wealthy', [], [], []),
#  ('starry night', 'allow', 'second story bedroom', [], [], []),
#  ('starry night', 'allow', 'use', [], [], []),
#  ('starry night', 'allow', 'painting studio', [], [], []),
#  ('starry night', 'allow', 'year', [], [], []),
#  ('starry night', 'continue', 'asylum', [], [], []),
#  ('starry night', 'continue', 'paintings', [], [], []),
#  ('starry night', 'continue', 'arles', [], [], []),
#  ('starry night', 'produce', 'period', [], [], []),
#  ('starry night', 'produce', 'best known works', [], [], []),
#  ('starry night', 'produce', 'career', [], [], []),
#  ('starry night', 'produce', 'irises', [], [], []),
#  ('starry night', 'produce', 'j. paul getty museum', [], [], []),
#  ('starry night', 'paint', 'september', [], [], []),
#  ('starry night', 'paint', 'musée', [], [], []),
#  ('starry night', 'paint', '18 june', [], [], []),
#  ('starry night', 'say', 'brother', [], [], []),
#  ('starry night', 'say', 'new study', [], [], []),
#  ('starry night', 'say', 'starry sky', [], [], []),
#  ('starry night', 'paint', 'day', [], [], []),
#  ('starry night', 'paint', 'van gogh ground floor studio', [], [], []),
#  ('starry night', 'identify', 'memory', [], [], []),
#  ('starry night', 'face', 'bedroom window', [], [], []),
#  ('starry night', 'face', 'east', [], [], []),
#  ('starry night', 'face', 'variations', [], [], []),
#  ('starry night', 'face', 'fewer times', [], [], []),
#  ('starry night', 'write', 'iron barred window', [], [], []),
#  ('starry night', 'write', 'enclosed square', [], [], []),
#  ('starry night', 'write', 'wheat', [], [], []),
#  ('starry night', 'depict', 'morning', [], [], []),
#  ('starry night', 'depict', 'glory', [], [], []),
#  ('starry night', 'depict', 'different times', [], [], []),
#  ('starry night', 'depict', 'weather conditions', [], [], []),
#  ('starry night',
#   'depict',
#   'sunrise moonrise sunshine filled days',
#   [],
#   [],
#   []),
#  ('starry night', 'allow', 'rain', [], [], []),
#  ('starry night', 'allow', 'bedroom', [], [], []),
#  ('starry night', 'base', 'sketches', [], [], []),
#  ('starry night', 'base', 'ink', [], [], []),
#  ('starry night', 'base', 'paper', [], [], []),
#  ('starry night', 'base', 'newer variations', [], [], []),
#  ('starry night', 'base', 'previous versions', [], [], []),
#  ('starry night', 'be', 'diagonal line', [], [], []),
#  ('starry night', 'be', 'right', [], [], []),
#  ('starry night', 'be', 'low rolling hills', [], [], []),
#  ('starry night', 'be', 'alpilles mountains', [], [], []),
#  ('starry night', 'be', 'versions', [], [], []),
#  ('starry night', 'be', 'far wall', [], [], []),
#  ('starry night', 'telescope', 'wheat field', [], [], []),
#  ('starry night', 'bring', 'f717 wheat field', [], [], []),
#  ('starry night', 'bring', 'cypresses', [], [], []),
#  ('starry night', 'bring', 'trees', [], [], []),
#  ('starry night', 'bring', 'picture plane', [], [], []),
#  ('starry night', 'be', 'f611 mountainous landscape', [], [], []),
#  ('starry night', 'be', 'saint rémy', [], [], []),
#  ('starry night', 'make', 'copenhagen', [], [], []),
#  ('starry night', 'make', 'number', [], [], []),
#  ('starry night', 'be', 'enclosed wheatfield', [], [], []),
#  ('starry night', 'be', 'storm', [], [], []),
#  ('starry night', 'be', 'studio', [], [], []),
#  ('starry night', 'mention', '9 june letter', [], [], []),
#  ('starry night', 'describe', 'days', [], [], []),
#  ('starry night', 'describe', 'second', [], [], []),
#  ('starry night', 'describe', 'landscapes', [], [], []),
#  ('starry night', 'be', 'letter', [], [], []),
#  ('starry night', 'be', 'sister', [], [], []),
#  ('starry night', 'be', '16 june', [], [], []),
#  ('starry night', 'be', 'f719 green wheat field', [], [], []),
#  ('starry night', 'be', 'cypress', [], [], []),
#  ('starry night', 'be', 'prague', [], [], []),
#  ('starry night', 'F1548', 'plein air', [], [], []),
#  ('starry night', 'be', 'new york', [], [], []),
#  ('starry night', 'be', 'study', [], [], []),
#  ('starry night', 'state', 'theo', [], [], []),
#  ('starry night', 'be', 'nocturne', [], [], []),
#  ('starry night', 'be', 'series', [], [], []),
#  ('starry night', 'be', 'views', [], [], []),
#  ('starry night', 'write', 'early june', [], [], []),
#  ('starry night', 'write', 'countryside', [], [], []),
#  ('starry night', 'write', 'window', [], [], []),
#  ('starry night', 'determine', 'morning star', [], [], []),
#  ('starry night', 'determine', 'dawn', [], [], []),
#  ('starry night', 'determine', 'spring', [], [], []),
#  ('starry night', 'be', 'time', [], [], []),
#  ('starry night', 'be', 'viewer right', [], [], []),
#  ('starry night', 'be', 'cypress tree', [], [], []),
#  ('starry night', 'be', 'venus', [], [], []),
#  ('starry night', 'be', 'picture', [], [], []),
#  ('starry night', 'be', 'moon', [], [], []),
#  ('starry night', 'be', 'waning crescent', [], [], []),
#  ('starry night', 'see', 'interpretations', [], [], []),
#  ('starry night', 'be', 'van gogh cell', [], [], []),
#  ('starry night', 'be', 'village', [], [], []),
#  ('starry night', 'be', 'sketch f1541v', [], [], []),
#  ('starry night', 'think', 'hillside', [], [], []),
#  ('starry night', 'think', 'provençal', [], [], []),
#  ('starry night', 'think', 'van gogh', [], [], []),
#  ('starry night', 'think', 'nuenen period', [], [], []),
#  ('starry night', 'think', 'reminisces', [], [], []),
#  ('starry night', 'think', 'north', [], [], []),
#  ('starry night', 'think', 'landscape', [], [], []),
#  ('starry night', 'think', 'reverse f1541r', [], [], []),
#  ('starry night', 'say', 'large number', [], [], []),
#  ('starry night', 'say', 'letters', [], [], []),
#  ('starry night', 'include', 'list', [], [], []),
#  ('starry night', 'refer', 'paris', [], [], []),
#  ('starry night', 'refer', 'night study', [], [], []),
#  ('starry night', 'refer', 'things', [], [], []),
#  ('starry night', 'refer', 'little good', [], [], []),
#  ('starry night', 'include', 'blue hills', [], [], []),
#  ('starry night', 'include', 'quarry', [], [], []),
#  ('starry night', 'decide', 'batch', [], [], []),
#  ('starry night', 'be', 'order', [], [], []),
#  ('starry night', 'be', 'money', [], [], []),
#  ('starry night', 'be', 'postage', [], [], []),
#  ('starry night', 'refer', 'émile bernard', [], [], []),
#  ('starry night', 'refer', 'late november', [], [], []),
#  ('starry night', 'argue', 'failure', [], [], []),
#  ('starry night', 'argue', 'bernard', [], [], []),
#  ('starry night', 'prefer', 'nature', [], [], []),
#  ('starry night', 'prefer', 'abstractions', [], [], []),
#  ('starry night', 'recount', 'imagination', [], [], []),
#  ('starry night', 'recount', 'experiences', [], [], []),
#  ('starry night', 'live', 'weeks', [], [], []),
#  ('starry night', 'live', 'autumn', [], [], []),
#  ('starry night', 'know', 'abstraction', [], [], []),
#  ('starry night', 'be', 'delusion', [], [], []),
#  ('starry night', 'allow', 'brick wall', [], [], []),
#  ('starry night', 'allow', 'stars', [], [], []),
#  ('starry night', 'refer', 'fill', [], [], []),
#  ('starry night', 'refer', 'expressionistic swirls', [], [], []),
#  ('starry night', 'refer', 'upper center portion', [], [], []),
#  ('starry night', 'refer', 'pictorial elements', [], [], []),
#  ('starry night', 'refer', 'vincent', [], [], []),
#  ('starry night', 'feel', 'new canvases', [], [], []),
#  ('starry night', 'feel', 'moonlight', [], [], []),
#  ('starry night', 'feel', 'style', [], [], []),
#  ('starry night', 'feel', 'real sentiment', [], [], []),
#  ('starry night', 'feel', 'early november', [], [], []),
#  ('starry night', 'be', 'previous letter', [], [], []),
#  ('starry night', 'be', 'qualities', [], [], []),
#  ('starry night', 'be', 'long run', [], [], []),
#  ('starry night', 'urge', 'long sinuous lines', [], [], []),
#  ('starry night', 'urge', 'consignment', [], [], []),
#  ('starry night', 'urge', 'means', [], [], []),
#  ('starry night', '"But', 'drawing style', [], [], []),
#  ('starry night', '"But', 'entanglement', [], [], []),
#  ('starry night', '"But', 'masses', [], [], []),
#  ('starry night', 'defend', 'practices', [], [], []),
#  ('starry night', 'defend', 'gauguin', [], [], []),
#  ('starry night', 'defend', 'preferred method', [], [], []),
#  ('starry night', 'favor', 'impressionists', [], [], []),
#  ('starry night', 'paint', 'sunflowers', [], [], []),
#  ('starry night', 'belong', 'small series', [], [], []),
#  ('starry night', 'limit', 'nocturnes', [], [], []),
#  ('starry night', 'limit', 'difficulties', [], [], []),
#  ('starry night', 'limit', 'scenes', [], [], []),
#  ('starry night', 'be', 'night', [], [], []),
#  ('starry night', 'be', 'café terrace', [], [], []),
#  ('starry night', 'paint', 'early september', [], [], []),
#  ('starry night', 'follow', 'rhône', [], [], []),
#  ('starry night', 'provide', 'insight', [], [], []),
#  ('starry night', 'provide', 'intentions', [], [], []),
#  ('starry night', 'provide', 'night studies', [], [], []),
#  ('starry night', 'write', 'arrival', [], [], []),
#  ('starry night', 'write', 'february', [], [], []),
#  ('starry night', 'write', 'field', [], [], []),
#  ('starry night', 'write', 'ripe wheat', [], [], []),
#  ('starry night', 'write', 'beautiful nights', [], [], []),
#  ('starry night', 'go', 'daytime', [], [], []),
#  ('starry night', 'go', 'green meadow', [], [], []),
#  ('starry night', 'compare', 'dandelions', [], [], []),
#  ('starry night', 'compare', 'dots', [], [], []),
#  ('starry night', 'take', 'map', [], [], []),
#  ('starry night', 'take', 'train', [], [], []),
#  ('starry night', 'reach', 'earth', [], [], []),
#  ('starry night', 'reach', 'death', [], [], []),
#  ('starry night', 'reach', 'star', [], [], []),
#  ('starry night', 'reach', 'point', [], [], []),
#  ('starry night', 'disillusion', 'life', [], [], []),
#  ('starry night', 'appear', 'religion', [], [], []),
#  ('starry night', 'appear', 'belief', [], [], []),
#  ('starry night', 'appear', 'afterlife', [], [], []),
#  ('starry night', 'appear', 'ambivalence', [], [], []),
#  ('starry night', 'confess', 'tremendous need', [], [], []),
#  ('starry night', 'go', 'word', [], [], []),
#  ('starry night', 'write', 'dimension', [], [], []),
#  ('starry night', 'be', 'night sky', [], [], []),
#  ('starry night', 'be', 'terrible things', [], [], []),
#  ('starry night', 'have', 'hemisphere', [], [], []),
#  ('starry night', 'write', 'planet', [], [], []),
#  ('starry night', 'state', 'return', [], [], []),
#  ('starry night', 'state', 'romantic', [], [], []),
#  ('starry night', 'highlight', 'religious ideas', [], [], []),
#  ('starry night', 'highlight', 'expressionistic aspects', [], [], []),
#  ('starry night', 'say', 'pressure', [], [], []),
#  ('starry night', 'say', 'feeling', [], [], []),
#  ('starry night', 'theorize', 'visionary', [], [], []),
#  ('starry night', 'theorize', 'religious mood', [], [], []),
#  ('starry night', 'theorize', 'work', [], [], []),
#  ('starry night', 'reveal', 'reference', [], [], []),
#  ('starry night', 'reveal', 'new testament book', [], [], []),
#  ('starry night', 'reveal', 'revelation', [], [], []),
#  ('starry night', 'reveal', 'apocalyptic theme', [], [], []),
#  ('starry night', 'reveal', 'woman', [], [], []),
#  ('starry night', 'reveal', 'pain', [], [], []),
#  ('starry night', 'reveal', 'birth', [], [], []),
#  ('starry night', 'reveal', 'sun', [], [], []),
#  ('starry night', 'profess', 'dragon', [], [], []),
#  ('starry night', 'profess', 'volume', [], [], []),
#  ('starry night', 'profess', 'image', [], [], []),
#  ('starry night', 'profess', 'mother', [], [], []),
#  ('starry night', 'profess', 'clouds', [], [], []),
#  ('starry night', 'profess', 'olive trees', [], [], []),
#  ('starry night', 'call', 'pendant', [], [], []),
#  ('starry night', 'call', 'schapiro approach', [], [], []),
#  ('starry night', 'call', 'visionary painting', [], [], []),
#  ('starry night', 'write', 'state', [], [], []),
#  ('starry night', 'write', 'great agitation', [], [], []),
#  ('starry night', 'write', 'hallucinatory character', [], [], []),
#  ('starry night', 'take', 'pains', [], [], []),
#  ('starry night', 'compare', 'van gogh incapacitating breakdowns', [], [], []),
#  ('starry night',
#   'compare',
#   'van gogh religiously inclined longing',
#   [],
#   [],
#   []),
#  ('starry night', 'call', 'poetry', [], [], []),
#  ('starry night', 'call', 'walt whitman', [], [], []),
#  ('starry night', 'call', 'final absorption', [], [], []),
#  ('starry night', 'call', 'artist', [], [], []),
#  ('starry night', 'call', 'cosmos', [], [], []),
#  ('starry night', 'praise', 'forgotten sensation', [], [], []),
#  ('starry night', 'praise', 'threshold', [], [], []),
#  ('starry night', 'praise', 'eternity', [], [], []),
#  ('starry night', 'praise', 'schapiro eloquent interpretation', [], [], []),
#  ('starry night', 'praise', 'apocalyptic vision', [], [], []),
#  ('starry night', 'praise', 'symbolist theory', [], [], []),
#  ('starry night', 'assert', 'joseph dreams', [], [], []),
#  ('starry night', 'assert', 'old testament book', [], [], []),
#  ('starry night', 'assert', 'genesis', [], [], []),
#  ('starry night', 'assert', 'purely symbolic terms', [], [], []),
#  ('starry night', 'find', 'tree', [], [], []),
#  ('starry night', 'find', 'mediterranean countries', [], [], []),
#  ('starry night', 'find', 'symbolist subtext', [], [], []),
#  ('starry night', 'say', 'traditional religious subject', [], [], []),
#  ('starry night', 'say', 'disguise', [], [], []),
#  ('starry night', 'cite', 'sublimated image', [], [], []),
#  ('starry night', 'cite', 'deepest religious feelings', [], [], []),
#  ('starry night', 'cite', 'van gogh avowed admiration', [], [], []),
#  ('starry night', 'cite', 'eugène delacroix', [], [], []),
#  ('starry night', 'theorize', 'yellow', [], [], []),
#  ('starry night', 'theorize', 'christ', [], [], []),
#  ('starry night', 'theorize', 'colors', [], [], []),
#  ('starry night',
#   'criticize',
#   'schapiro loevgren biblical interpretations',
#   [],
#   [],
#   []),
#  ('starry night', 'be', 'reading', [], [], []),
#  ('starry night', 'be', 'crescent moon', [], [], []),
#  ('starry night', 'say', 'elements', [], [], []),
#  ('starry night', 'be', 'symbolic meaning', [], [], []),
#  ('starry night', 'be', 'consolation', [], [], []),
#  ('starry night', 'be', 'light', [], [], []),
#  ('starry night', 'be', 'symbolist interpretations', [], [], []),
#  ('starry night', 'prove', 'topographical elements', [], [], []),
#  ('starry night', 'prove', 'van gogh view', [], [], []),
#  ('starry night', 'identify', 'asylum window', [], [], []),
#  ('starry night', 'suggest', 'gibbous moon', [], [], []),
#  ('starry night', 'suggest', 'traditional image', [], [], []),
#  ('starry night', 'recount', 'resulting crescent', [], [], []),
#  ('starry night', 'recount', 'remnant', [], [], []),
#  ('starry night', 'recount', 'original gibbous version', [], [], []),
#  ('starry night', 'recount', 'van gogh interest', [], [], []),
#  ('starry night', 'recount', 'writings', [], [], []),
#  ('starry night', 'recount', 'victor hugo', [], [], []),
#  ('starry night', 'recount', 'possible inspiration', [], [], []),
#  ('starry night', 'provide', 'detailed discussion', [], [], []),
#  ('starry night', 'provide', 'publicized advances', [], [], []),
#  ('starry night', 'assert', 'astronomy', [], [], []),
#  ('starry night', 'assert', 'place', [], [], []),
#  ('starry night', 'assert', 'van gogh lifetime', [], [], []),
#  ('starry night', 'mention', 'astronomer camille flammarion', [], [], []),
#  ('starry night',
#   'mention',
#   'flammarion popular illustrated publications',
#   [],
#   [],
#   []),
#  ('starry night', 'see', 'drawings', [], [], []),
#  ('starry night', 'see', 'spiral nebulae', [], [], []),
#  ('starry night', 'interpret', 'telescopes', [], [], []),
#  ('starry night', 'interpret', 'swirling figure', [], [], []),
#  ('starry night', 'interpret', 'central portion', [], [], []),
#  ('starry night', 'interpret', 'sky', [], [], []),
#  ('starry night', 'interpret', 'spiral galaxy', [], [], []),
#  ('starry night', 'assert', 'popular media', [], [], []),
#  ('starry night', 'represent', 'van gogh understanding', [], [], []),
#  ('starry night', 'represent', 'living dynamic place', [], [], []),
#  ('starry night', 'conduct', 'astronomical study', [], [], []),
#  ('starry night', 'share', 'boime', [], [], []),
#  ('starry night', 'share', 'entire career', [], [], []),
#  ('starry night', 'share', 'u.c.l.a', [], [], []),
#  ('starry night', 'share', 'boime certainty', [], [], []),
#  ('starry night', 'share', 'regard', [], [], []),
#  ('starry night', 'concur', 'constellation aries', [], [], []),
#  ('starry night', 'concur', 'visibility', [], [], []),
#  ('starry night', 'see', 'depiction', [], [], []),
#  ('starry night', 'give', 'credit', [], [], []),
#  ('starry night', 'give', 'original', [], [], []),
#  ('starry night',
#   'give',
#   'anglo irish astronomer william parsons',
#   [],
#   [],
#   []),
#  ('starry night', 'evoke', 'wind', [], [], []),
#  ('starry night', 'evoke', 'mistral', [], [], []),
#  ('starry night', 'evoke', 'profound effect', [], [], []),
#  ('starry night', 'be', 'seven months', [], [], []),
#  ('starry night', 'be', 'breakdown', [], [], []),
#  ('starry night', 'theorize', 'july', [], [], []),
#  ('starry night', 'theorize', 'blue', [], [], []),
#  ('starry night', 'theorize', 'horizon', [], [], []),
#  ('starry night', 'identify', 'recollection', [], [], []),
#  ('starry night', 'identify', 'van gogh dutch homeland', [], [], []),
#  ('starry night', 'be', 'sketch', [], [], []),
#  ('starry night', 'be', 'town', [], [], []),
#  ('starry night', 'be', 'case', [], [], []),
#  ('starry night', 'be', 'imaginary component', [], [], []),
#  ('starry night', 'associate', 'asylum bedroom', [], [], []),
#  ('starry night', 'associate', 'european culture', [], [], []),
#  ('starry night', 'be', 'subject', [], [], []),
#  ('starry night', 'be', 'open debate', [], [], []),
#  ('starry night', 'be', 'april 1888 letter', [], [], []),
#  ('starry night', 'refer', 'funereal cypresses', [], [], []),
#  ('starry night', 'be', 'stately oaks', [], [], []),
#  ('starry night', 'like', 'thoughts', [], [], []),
#  ('starry night', 'like', 'canvases', [], [], []),
#  ('starry night', 'mention', 'studies', [], [], []),
#  ('starry night', 'mention', 'difficult shade', [], [], []),
#  ('starry night', 'suggest', 'green', [], [], []),
#  ('starry night', 'suggest', 'formal qualities', [], [], []),
#  ('starry night', 'refer', 'symbolic connotation', [], [], []),
#  ('starry night', 'refer', 'vague symbol', [], [], []),
#  ('starry night', 'call', 'human striving', [], [], []),
#  ('starry night', 'call', 'symbolic counterpart', [], [], []),
#  ('starry night', 'call', 'striving', [], [], []),
#  ('starry night', 'call', 'infinite', [], [], []),
#  ('starry night', 'say', 'non orthodox channels', [], [], []),
#  ('starry night', 'provide', 'rustic natural obelisks', [], [], []),
#  ('starry night', 'provide', 'link', [], [], []),
#  ('starry night', 'provide', 'heavens', [], [], []),
#  ('starry night', 'remind', 'reader', [], [], []),
#  ('starry night', 'say', 'arbitrary collage', [], [], []),
#  ('starry night', 'say', 'separate motifs', [], [], []),
#  ('starry night', 'claim', 'van gogh room', [], [], []),
#  ('starry night', 'assert', 'products', [], [], []),
#  ('starry night', 'assert', 'van gogh imagination', [], [], []),
#  ('starry night', 'say', 'certain', [], [], []),
#  ('starry night', 'say', 'pictures', [], [], []),
#  ('starry night', 'serve', 'reason', [], [], []),
#  ('starry night', 'serve', 'depth', [], [], []),
#  ('starry night', 'serve', 'brightness', [], [], []),
#  ('starry night', 'use', 'van gogh statement', [], [], []),
#  ('starry night', 'use', 'exaggeration', [], [], []),
#  ('starry night', 'be', 'arrangement', [], [], []),
#  ('starry night', 'be', 'argument', [], [], []),
#  ('starry night', 'be', 'amalgam', [], [], []),
#  ('starry night', 'be', 'images', [], [], []),
#  ('starry night', 'speak', 'synonym', [], [], []),
#  ('starry night', 'speak', 'composition', [], [], []),
#  ('starry night', 'speak', 'fact', [], [], []),
#  ('starry night', 'speak', 'comment', [], [], []),
#  ('starry night', 'call', 'white cloud', [], [], []),
#  ('starry night', 'call', 'mountains', [], [], []),
#  ('starry night', 'call', 'exaggerations', [], [], []),
#  ('starry night', 'contort', 'ancient woodcuts', [], [], []),
#  ('starry night', 'acknowledge', 'realistic non composite views', [], [], []),
#  ('starry night', 'acknowledge', 'subjects', [], [], []),
#  ('starry night', 'be', 'exaggerated color', [], [], []),
#  ('starry night', 'be', 'type', [], [], []),
#  ('starry night', 'criticize', 'search', [], [], []),
#  ('starry night', 'use', 'occasions', [], [], []),
#  ('starry night', 'use', 'word arrangement', [], [], []),
#  ('starry night', 'use', 'color', [], [], []),
#  ('starry night', 'use', 'way', [], [], []),
#  ('starry night', 'write', 'term', [], [], []),
#  ('starry night', 'write', 'january', [], [], []),
#  ('starry night', 'move', 'colours', [], [], []),
#  ('starry night', 'intensify', 'pure oranges', [], [], []),
#  ('starry night', 'intensify', 'flesh', [], [], []),
#  ('starry night', 'intensify', 'tones', [], [], []),
#  ('starry night', 'intensify', 'chromes', [], [], []),
#  ('starry night', 'intensify', 'pinks', [], [], []),
#  ('starry night', 'devise', 'olive veronese greens', [], [], []),
#  ('starry night', 'devise', 'impressionist arrangement', [], [], []),
#  ('starry night', 'be', 'la berceuse', [], [], []),
#  ('starry night', 'be', 'realistic portrait', [], [], []),
#  ('starry night', 'be', 'augustine roulin', [], [], []),
#  ('starry night', 'be', 'imaginative floral background', [], [], []),
#  ('starry night', 'be', 'meadow', [], [], []),
#  ('starry night', 'discuss', 'hallucinatory vision', [], [], []),
#  ('starry night', 'discuss', 'context', [], [], []),
#  ('starry night', 'discuss', 'van gogh mental illness', [], [], []),
#  ('starry night', 'know', 'temporal lobe epilepsy', [], [], []),
#  ('starry night', 'know', 'antiquity', [], [], []),
#  ('starry night', 'cause', 'limbs', [], [], []),
#  ('starry night', 'cause', 'jerk', [], [], []),
#  ('starry night', 'call', 'falling sickness', [], [], []),
#  ('starry night', 'call', 'mind', [], [], []),
#  ('starry night', 'call', 'thought', [], [], []),
#  ('starry night', 'symptom', 'brain', [], [], []),
#  ('starry night', 'symptom', 'bizarre dramatic behavior', [], [], []),
#  ('starry night', 'symptom', 'seizures', [], [], []),
#  ('starry night', 'experience', 'electrical impulses', [], [], []),
#  ('starry night', 'experience', 'second breakdown', [], [], []),
#  ('starry night', 'throw', 'mid', [], [], []),
#  ('starry night', 'throw', 'heightened reality', [], [], []),
#  ('starry night', 'send', 'ordinary eyes', [], [], []),
#  ('starry night', 'send', '28 september', [], [], []),
#  ('starry night', 'become', 'caretaker', [], [], []),
#  ('starry night', 'become', 'van gogh legacy', [], [], []),
#  ('starry night', 'poet', 'julien leclercq', [], [], []),
#  ('starry night', 'sell', 'gauguin old friend', [], [], []),
#  ('starry night', 'buy', 'schuffenecker', [], [], []),
#  ('starry night', 'own', 'oldenzeel gallery', [], [], []),
#  ('starry night', 'own', 'rotterdam', [], [], []),
#  ('starry night', 'own', 'georgette p. van stolk', [], [], []),
#  ('starry night', 'be', 'paul rosenberg', [], [], []),
#  ('starry night', 'be', 'rosenberg', [], [], []),
#  ('starry night', 'investigate', 'scientists', [], [], []),
#  ('starry night', 'investigate', 'rochester institute', [], [], []),
#  ('starry night', 'investigate', 'technology', [], [], []),
#  ('starry night', 'exhibit', 'rare pigment indian yellow', [], [], []),
#  ('starry night', 'exhibit', 'van gogh starry night', [], [], []),
#  ('starry night', 'see', 'baldin collection vincent', [], [], []),
#  ('starry night', 'see', 'don mclean', [], [], []),
#  ('starry night', 'see', 'tribute', [], [], []),
#  ('starry night', 'see', 'vincent van gogh timbres', [], [], []),
#  ('starry night', 'Citations Letters Sources', 'henri dutilleux', [], [], []),
#  ('starry night', 'the Starry Night', 'metropolitan museum', [], [], []),
#  ('starry night', 'the Starry Night', 'art libraries', [], [], []),
#  ('starry night', 'the Starry Night', 'material', [], [], []),
#  ('starry night', 'the Starry Night', 'aerial photo', [], [], []),
#  ('starry night', 'the Starry Night', 'vincent bedroom archived', [], [], []),
#  ('starry night',
#   'the Starry Night',
#   'wayback machine vincent van gogh',
#   [],
#   [],
#   []),
#  ('starry night', 'the Starry Night', 'history', [], [], [])]

# %%
import wikipediaapi  # pip install wikipedia-api
import pandas as pd
import concurrent.futures
from tqdm import tqdm

# %%
def wiki_scrape(name_topic, verbose=True):
   def link_to_wikipedia(link):
       try:
           page = api_wikipedia.page(link)
           if page.exists():
               return {'page': link, 'text': page.text, 'link': page.fullurl, 'categories': list(page.categories.keys())}
       except:
           return None
      
   api_wikipedia = wikipediaapi.Wikipedia(language='en', extract_format=wikipediaapi.ExtractFormat.WIKI)
   name_of_page = api_wikipedia.page(name_topic)
   if not name_of_page.exists():
       print('Page {} is not present'.format(name_of_page))
       return
  
   links_to_page = list(name_of_page.links.keys())
   procceed = tqdm(desc='Scraped links', unit='', total=len(links_to_page)) if verbose else None
   origin = [{'page': name_topic, 'text': name_of_page.text, 'link': name_of_page.fullurl, 'categories': list(name_of_page.categories.keys())}]
  
   with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
       links_future = {executor.submit(link_to_wikipedia, link): link for link in links_to_page}
       for future in concurrent.futures.as_completed(links_future):
           info = future.result()
           origin.append(info) if info else None
           procceed.update(1) if verbose else None
   procceed.close() if verbose else None
  
   namespaces = ('Wikipedia', 'Special', 'Talk', 'LyricWiki', 'File', 'MediaWiki',
                 'Template', 'Help', 'User', 'Category talk', 'Portal talk')
   origin = pd.DataFrame(origin)
   origin = origin[(len(origin['text']) > 20)
                     & ~(origin['page'].str.startswith(namespaces, na=True))]
   origin['categories'] = origin.categories.apply(lambda a: [b[9:] for b in a])

   origin['topic'] = name_topic
   print('Scraped pages', len(origin))
  
   return origin

# %%
wiki_data = wiki_scrape('mozart')
# Out:
# Scraped links: 100%|██████████| 500/500 [01:57<00:00,  4.26/s]
# Scraped pages 472

# %%
from spacy import displacy

# %%
text= wikipedia.page('Mozart').content
text
article = nlp(text)
sentences = [x for x in article.sents]

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4cad7028293a4831bf531b660a8ccc6f-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">1743,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">appointed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">fourth violinist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the musical establishment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Count Leopold Anton von Firmian,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the ruling Prince-Archbishop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Salzburg.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 750.0,2.0 750.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-1" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-2" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4cad7028293a4831bf531b660a8ccc6f-0-6" stroke-width="2px" d="M770,352.0 C770,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4cad7028293a4831bf531b660a8ccc6f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,354.0 L1278.0,342.0 1262.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="di
